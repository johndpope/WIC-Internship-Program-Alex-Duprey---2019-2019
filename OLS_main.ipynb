# %%
import OLS_regression_analysis
import bbgclient
import datetime
import dfutils
import pandas as pd
# Out:
# ImportErrorTraceback (most recent call last)
# <ipython-input-2-9802f03cad8b> in <module>()
# ----> 1 import OLS_regression_analysis
#       2 import bbgclient
#       3 import datetime
#       4 import dfutils
#       5 import pandas as pd
#
# C:\Users\aduprey\OLS_regression_analysis.py in <module>()
#       9 utils = importr('utils')
#      10
# ---> 11 import bbgclient
#      12 import dfutils
#      13 import datetime
#
# C:\Users\aduprey\bbgclient.py in <module>()
#       3 import datetime
#       4 import dbutils
# ----> 5 import urllib.request
#       6 import pandas as pd
#       7
#
# ImportError: No module named request

# %%
metrics = ['P/E', "EV/EBITDA", "EV/Sales", 'DVD Yield', 'FCF Yield']
alpha_ticker = 'PZZA US EQUITY'
analyst_upside = 54.50
analyst_downside = 29.05
analyst_pt_wic = 45
lookback = 120
unaffected_date = '2018-07-11'
target_date = "2019-02-08"
api_host = bbgclient.bbgclient.get_next_available_host()
fperiod = "1BF"

# %%
#def run_OLS_regression_analysis(alpha_ticker, lookback, unaffectedDt, tgtDate, analyst_upside, api_host, metrics, f_period = '1BF'):

    #OLS_results = OLS_regression_analysis.premium_analysis_df_OLS(alpha_ticker, analyst_upside, lookback, unaffectedDt, tgtDate, metrics, api_host, fperiod = "1BF")

    #calib_results = OLS_regression_analysis.calibration_data(alpha_ticker, OLS_results, metrics)

    #premium_analysis_results = OLS_regression_analysis.premium_analysis_df(alpha_ticker, tgtDate, analyst_upside, calib_results, api_host)

    #return(OLS_results)

#output = run_OLS_regression_analysis(alpha_ticker, lookback, unaffected_date, target_date, analyst_upside, api_host, metrics, f_period = '1BF')

# %%
#RUN THIS FUNCTION TO START. BELOW FUNCTION HAS EXTRA CHANGES.
OlS_results = OLS_regression_analysis.premium_analysis_df_OLS(alpha_ticker, analyst_upside, lookback, unaffected_date, target_date, metrics, api_host, fperiod = '1BF')
# Out:
# WARNING: BJRI US EQUITY for BEST_CAPEX between 20180118 and 20180711 return mismatch date-value
# WARNING: DFRG US EQUITY for BEST_OPP between 20180118 and 20180711 return mismatch date-value
# WARNING: FRSH US EQUITY for BEST_EBITDA between 20180919 and 20190208 return mismatch date-value
# WARNING: FRSH US EQUITY for BEST_OPP between 20180919 and 20190208 return mismatch date-value
# WARNING: FRSH US EQUITY for BEST_NET_INCOME between 20180919 and 20190208 return mismatch date-value
# WARNING: DIN US EQUITY for BEST_EBITDA between 20180919 and 20190208 return mismatch date-value
# WARNING: FRGI US EQUITY for BEST_EBITDA between 20180919 and 20190208 return mismatch date-value
# WARNING: FRGI US EQUITY for BEST_OPP between 20180919 and 20190208 return mismatch date-value
# WARNING: FRGI US EQUITY for BEST_CAPEX between 20180919 and 20190208 return mismatch date-value
# WARNING: FRGI US EQUITY for BEST_NET_INCOME between 20180919 and 20190208 return mismatch date-value
# WARNING: CHUY US EQUITY for BEST_CAPEX between 20180919 and 20190208 return mismatch date-value
# WARNING: FRSH US EQUITY for BEST_EBITDA between 20181002 and 20190221 return mismatch date-value
# WARNING: FRSH US EQUITY for BEST_OPP between 20181002 and 20190221 return mismatch date-value
# WARNING: FRSH US EQUITY for BEST_NET_INCOME between 20181002 and 20190221 return mismatch date-value
# WARNING: DIN US EQUITY for BEST_EBITDA between 20181002 and 20190221 return mismatch date-value
# WARNING: FRGI US EQUITY for BEST_EBITDA between 20181002 and 20190221 return mismatch date-value
# WARNING: FRGI US EQUITY for BEST_OPP between 20181002 and 20190221 return mismatch date-value
# WARNING: FRGI US EQUITY for BEST_CAPEX between 20181002 and 20190221 return mismatch date-value
# WARNING: FRGI US EQUITY for BEST_NET_INCOME between 20181002 and 20190221 return mismatch date-value
# WARNING: CHUY US EQUITY for BEST_CAPEX between 20181002 and 20190221 return mismatch date-value
# {'WING US EQUITY': -0.09475927890979512, 'WEN US EQUITY': 0.28272480883829304, 'MCD US EQUITY': -0.885292951334438, 'YUM US EQUITY': 0.6776259146140193, 'FRSH US EQUITY': 0.1462630232912526, 'YUMC US EQUITY': -0.1317077148983311, 'DNKN US EQUITY': -0.33708272618556057, 'CMG US EQUITY': -0.20457132266072373, 'SBUX US EQUITY': 0.5256463231007172, 'DENN US EQUITY': 0.16822005023863323, 'BJRI US EQUITY': -0.4053238680635289, 'EAT US EQUITY': 1.0645102653301766, 'DIN US EQUITY': 0.4373661214944077, 'RRGB US EQUITY': -0.1258786315971421, 'CHUY US EQUITY': 0.5009749384763811, 'TXRH US EQUITY': 0.4820275085758823, 'PLAY US EQUITY': -0.3728226203143159, '(Intercept)': 0.17103007306366366}
# {'JACK US EQUITY': 0.10908916825563365, 'MCD US EQUITY': -0.6664755819772273, 'YUM US EQUITY': 0.32654035203338266, 'QSR CN EQUITY': -0.2015789304995831, 'YUMC US EQUITY': 0.18999989202586584, 'PBPB US EQUITY': 0.280244862776155, 'CMG US EQUITY': -0.11452823783669805, 'SBUX US EQUITY': 0.3650318861250458, 'CBRL US EQUITY': 0.47583534816903245, 'DENN US EQUITY': 0.3976161153651718, 'BJRI US EQUITY': -0.5039235466467108, 'EAT US EQUITY': 1.2042262926052236, 'BLMN US EQUITY': 0.6618149079175575, 'RRGB US EQUITY': -0.24007767016285672, 'CHUY US EQUITY': 0.32596138697734106, 'DFRG US EQUITY': 0.29851183751983257, 'PLAY US EQUITY': -0.24720245141559485, '(Intercept)': -9.817530222024807}
# {'WING US EQUITY': -0.01744142426704707, 'MCD US EQUITY': -0.02774072147577836, 'YUM US EQUITY': 0.0352748182286452, 'FRSH US EQUITY': 0.043214061981843986, 'DPZ US EQUITY': 0.07549711648444916, 'SHAK US EQUITY': 0.07052698971335815, 'NDLS US EQUITY': -0.17592805092755562, 'SBUX US EQUITY': 0.09984512697269125, 'CBRL US EQUITY': 0.6036041668438176, 'BJRI US EQUITY': -0.3689423165077394, 'EAT US EQUITY': 0.9036562514673264, 'CAKE US EQUITY': 0.25830012668099467, 'RRGB US EQUITY': -0.2174774016026028, 'DFRG US EQUITY': 0.3726460143819268, 'PLAY US EQUITY': -0.2279486795319603, '(Intercept)': -0.6744491102445839}
# {'WING US EQUITY': -0.3616988251552871, 'YUM US EQUITY': 0.49776883030804453, 'QSR CN EQUITY': 0.023543025210216038, 'YUMC US EQUITY': 0.23907632635213344, 'DPZ US EQUITY': -0.4450903077290256, 'DNKN US EQUITY': -0.25128167558387127, 'SBUX US EQUITY': -0.05563741658523403, 'CBRL US EQUITY': 0.3836821630552113, 'BJRI US EQUITY': -0.27639317085167114, 'DIN US EQUITY': 0.058953622970539875, 'BLMN US EQUITY': 0.21995655017184718, 'TXRH US EQUITY': 0.5232692808805605, '(Intercept)': -0.631971444661008}
# {'MCD US EQUITY': -0.56548090171423, 'YUM US EQUITY': 0.3802097476544719, 'YUMC US EQUITY': -0.15794150097115517, 'DPZ US EQUITY': 0.1447284480645654, 'NDLS US EQUITY': 0.03487515963947618, 'DNKN US EQUITY': -0.4686599497566478, 'CMG US EQUITY': -0.24220205929928051, 'SBUX US EQUITY': 0.2320380551896031, 'DENN US EQUITY': 0.09948279257218137, 'BJRI US EQUITY': -0.2702465182024461, 'EAT US EQUITY': 0.1265782947766365, 'DIN US EQUITY': 0.07208169915830302, 'CHUY US EQUITY': 0.4130292278126905, 'TXRH US EQUITY': 0.9452660820239567, 'PLAY US EQUITY': 0.07277773844695795, '(Intercept)': 0.025827750980302065}
# {'YUM US EQUITY': 1.2716284586285151, 'SBUX US EQUITY': 0.006726528249078454, 'BJRI US EQUITY': 0.28280545601686286, 'Intercept': -15.760730427421798}
# {'YUM US EQUITY': 1.214507629052481, 'SBUX US EQUITY': 0.006730361250070584, 'BJRI US EQUITY': 0.053368882933437035, 'Intercept': -8.83441997005396}
# {'YUM US EQUITY': 0.0337918846407029, 'SBUX US EQUITY': 0.18172412407009308, 'BJRI US EQUITY': -0.0899783849203583, 'Intercept': 0.6362708850140979}
# {'YUM US EQUITY': 0.5408258639451214, 'SBUX US EQUITY': 0.05374232563544, 'BJRI US EQUITY': -0.44772707068449696, 'Intercept': 0.9391005448068245}
# {'YUM US EQUITY': 0.9331320027442087, 'SBUX US EQUITY': -0.11183304898579234, 'BJRI US EQUITY': 0.18911638145617993, 'Intercept': -0.003573056601562834}

# %%
OlS_results
# Out:
# {'optimal_peer_results': {'P/E': {'Optimal Peers': ['WING US EQUITY',
#     'WEN US EQUITY',
#     'MCD US EQUITY',
#     'YUM US EQUITY',
#     'FRSH US EQUITY',
#     'YUMC US EQUITY',
#     'DNKN US EQUITY',
#     'CMG US EQUITY',
#     'SBUX US EQUITY',
#     'DENN US EQUITY',
#     'BJRI US EQUITY',
#     'EAT US EQUITY',
#     'DIN US EQUITY',
#     'RRGB US EQUITY',
#     'CHUY US EQUITY',
#     'TXRH US EQUITY',
#     'PLAY US EQUITY'],
#    'Alpha Downside': 27.009706687060504,
#    'Alpha Upside': 53.44841808470018},
#   'EV/EBITDA': {'Optimal Peers': ['JACK US EQUITY',
#     'MCD US EQUITY',
#     'YUM US EQUITY',
#     'QSR CN EQUITY',
#     'YUMC US EQUITY',
#     'PBPB US EQUITY',
#     'CMG US EQUITY',
#     'SBUX US EQUITY',
#     'CBRL US EQUITY',
#     'DENN US EQUITY',
#     'BJRI US EQUITY',
#     'EAT US EQUITY',
#     'BLMN US EQUITY',
#     'RRGB US EQUITY',
#     'CHUY US EQUITY',
#     'DFRG US EQUITY',
#     'PLAY US EQUITY'],
#    'Alpha Downside': nan,
#    'Alpha Upside': nan},
#   'EV/Sales': {'Optimal Peers': ['WING US EQUITY',
#     'MCD US EQUITY',
#     'YUM US EQUITY',
#     'FRSH US EQUITY',
#     'DPZ US EQUITY',
#     'SHAK US EQUITY',
#     'NDLS US EQUITY',
#     'SBUX US EQUITY',
#     'CBRL US EQUITY',
#     'BJRI US EQUITY',
#     'EAT US EQUITY',
#     'CAKE US EQUITY',
#     'RRGB US EQUITY',
#     'DFRG US EQUITY',
#     'PLAY US EQUITY'],
#    'Alpha Downside': nan,
#    'Alpha Upside': nan},
#   'DVD Yield': {'Optimal Peers': ['WING US EQUITY',
#     'YUM US EQUITY',
#     'QSR CN EQUITY',
#     'YUMC US EQUITY',
#     'DPZ US EQUITY',
#     'DNKN US EQUITY',
#     'SBUX US EQUITY',
#     'CBRL US EQUITY',
#     'BJRI US EQUITY',
#     'DIN US EQUITY',
#     'BLMN US EQUITY',
#     'TXRH US EQUITY'],
#    'Alpha Downside': 52.518082799822814,
#    'Alpha Upside': 54.50071862164158},
#   'FCF Yield': {'Optimal Peers': ['MCD US EQUITY',
#     'YUM US EQUITY',
#     'YUMC US EQUITY',
#     'DPZ US EQUITY',
#     'NDLS US EQUITY',
#     'DNKN US EQUITY',
#     'CMG US EQUITY',
#     'SBUX US EQUITY',
#     'DENN US EQUITY',
#     'BJRI US EQUITY',
#     'EAT US EQUITY',
#     'DIN US EQUITY',
#     'CHUY US EQUITY',
#     'TXRH US EQUITY',
#     'PLAY US EQUITY'],
#    'Alpha Downside': 100.63844042579268,
#    'Alpha Upside': 100.63844042579268}},
#  'overlap_peer_results': {'P/E': {'Overlap Peers': ['YUM US EQUITY',
#     'SBUX US EQUITY',
#     'BJRI US EQUITY'],
#    'Alpha Downside': 27.81045344366691,
#    'Alpha Upside': 53.32992865719318},
#   'EV/EBITDA': {'Overlap Peers': ['YUM US EQUITY',
#     'SBUX US EQUITY',
#     'BJRI US EQUITY'],
#    'Alpha Downside': nan,
#    'Alpha Upside': nan},
#   'EV/Sales': {'Overlap Peers': ['YUM US EQUITY',
#     'SBUX US EQUITY',
#     'BJRI US EQUITY'],
#    'Alpha Downside': nan,
#    'Alpha Upside': nan},
#   'DVD Yield': {'Overlap Peers': ['YUM US EQUITY',
#     'SBUX US EQUITY',
#     'BJRI US EQUITY'],
#    'Alpha Downside': 56.46538873075771,
#    'Alpha Upside': 56.46538873075771},
#   'FCF Yield': {'Overlap Peers': ['YUM US EQUITY',
#     'SBUX US EQUITY',
#     'BJRI US EQUITY'],
#    'Alpha Downside': 96.31260840052256,
#    'Alpha Upside': 96.31260840052256}}}

# %%
OlS_results2 = OLS_regression_analysis.premium_analysis_df_OLS2(alpha_ticker, analyst_upside, analyst_downside, analyst_pt_wic, lookback, unaffected_date, target_date, metrics, api_host, adjustments_df_now = None, adjustments_df_ptd = None, fperiod = '1BF')
# Out:
# WARNING: BJRI US EQUITY for BEST_CAPEX between 20180118 and 20180711 return mismatch date-value
# WARNING: DFRG US EQUITY for BEST_OPP between 20180118 and 20180711 return mismatch date-value
# WARNING: FRSH US EQUITY for BEST_EBITDA between 20180919 and 20190208 return mismatch date-value
# WARNING: FRSH US EQUITY for BEST_OPP between 20180919 and 20190208 return mismatch date-value
# WARNING: FRSH US EQUITY for BEST_NET_INCOME between 20180919 and 20190208 return mismatch date-value
# WARNING: DIN US EQUITY for BEST_EBITDA between 20180919 and 20190208 return mismatch date-value
# WARNING: FRGI US EQUITY for BEST_EBITDA between 20180919 and 20190208 return mismatch date-value
# WARNING: FRGI US EQUITY for BEST_OPP between 20180919 and 20190208 return mismatch date-value
# WARNING: FRGI US EQUITY for BEST_CAPEX between 20180919 and 20190208 return mismatch date-value
# WARNING: FRGI US EQUITY for BEST_NET_INCOME between 20180919 and 20190208 return mismatch date-value
# WARNING: CHUY US EQUITY for BEST_CAPEX between 20180919 and 20190208 return mismatch date-value
# WARNING: FRSH US EQUITY for BEST_EBITDA between 20181002 and 20190221 return mismatch date-value
# WARNING: FRSH US EQUITY for BEST_OPP between 20181002 and 20190221 return mismatch date-value
# WARNING: FRSH US EQUITY for BEST_NET_INCOME between 20181002 and 20190221 return mismatch date-value
# WARNING: DIN US EQUITY for BEST_EBITDA between 20181002 and 20190221 return mismatch date-value
# WARNING: FRGI US EQUITY for BEST_EBITDA between 20181002 and 20190221 return mismatch date-value
# WARNING: FRGI US EQUITY for BEST_OPP between 20181002 and 20190221 return mismatch date-value
# WARNING: FRGI US EQUITY for BEST_CAPEX between 20181002 and 20190221 return mismatch date-value
# WARNING: FRGI US EQUITY for BEST_NET_INCOME between 20181002 and 20190221 return mismatch date-value
# WARNING: CHUY US EQUITY for BEST_CAPEX between 20181002 and 20190221 return mismatch date-value

# %%
#OlS_results2

# %%
OlS_results2
# Out:
# {'optimal_peer_results': {'P/E': {'Optimal Peers': ['WING US EQUITY',
#     'WEN US EQUITY',
#     'MCD US EQUITY',
#     'YUM US EQUITY',
#     'FRSH US EQUITY',
#     'YUMC US EQUITY',
#     'DNKN US EQUITY',
#     'CMG US EQUITY',
#     'SBUX US EQUITY',
#     'DENN US EQUITY',
#     'BJRI US EQUITY',
#     'EAT US EQUITY',
#     'DIN US EQUITY',
#     'RRGB US EQUITY',
#     'CHUY US EQUITY',
#     'TXRH US EQUITY',
#     'PLAY US EQUITY'],
#    'Alpha Downside': 28.176955299485243,
#    'Alpha PT WIC': 44.126955299485246,
#    'Alpha Upside': 53.626955299485246},
#   'EV/EBITDA': {'Optimal Peers': ['JACK US EQUITY',
#     'MCD US EQUITY',
#     'YUM US EQUITY',
#     'QSR CN EQUITY',
#     'YUMC US EQUITY',
#     'PBPB US EQUITY',
#     'CMG US EQUITY',
#     'SBUX US EQUITY',
#     'CBRL US EQUITY',
#     'DENN US EQUITY',
#     'BJRI US EQUITY',
#     'EAT US EQUITY',
#     'BLMN US EQUITY',
#     'RRGB US EQUITY',
#     'CHUY US EQUITY',
#     'DFRG US EQUITY',
#     'PLAY US EQUITY'],
#    'Alpha Downside': nan,
#    'Alpha PT WIC': nan,
#    'Alpha Upside': nan},
#   'EV/Sales': {'Optimal Peers': ['WING US EQUITY',
#     'MCD US EQUITY',
#     'YUM US EQUITY',
#     'FRSH US EQUITY',
#     'DPZ US EQUITY',
#     'SHAK US EQUITY',
#     'NDLS US EQUITY',
#     'SBUX US EQUITY',
#     'CBRL US EQUITY',
#     'BJRI US EQUITY',
#     'EAT US EQUITY',
#     'RRGB US EQUITY',
#     'CAKE US EQUITY',
#     'DFRG US EQUITY',
#     'PLAY US EQUITY'],
#    'Alpha Downside': nan,
#    'Alpha PT WIC': nan,
#    'Alpha Upside': nan},
#   'DVD Yield': {'Optimal Peers': ['WING US EQUITY',
#     'YUM US EQUITY',
#     'QSR CN EQUITY',
#     'YUMC US EQUITY',
#     'DPZ US EQUITY',
#     'DNKN US EQUITY',
#     'SBUX US EQUITY',
#     'CBRL US EQUITY',
#     'BJRI US EQUITY',
#     'DIN US EQUITY',
#     'BLMN US EQUITY',
#     'TXRH US EQUITY'],
#    'Alpha Downside': 29.00728875973262,
#    'Alpha PT WIC': 44.95728875973262,
#    'Alpha Upside': 54.45728875973262},
#   'FCF Yield': {'Optimal Peers': ['MCD US EQUITY',
#     'YUM US EQUITY',
#     'YUMC US EQUITY',
#     'DPZ US EQUITY',
#     'NDLS US EQUITY',
#     'DNKN US EQUITY',
#     'CMG US EQUITY',
#     'SBUX US EQUITY',
#     'DENN US EQUITY',
#     'BJRI US EQUITY',
#     'EAT US EQUITY',
#     'DIN US EQUITY',
#     'CHUY US EQUITY',
#     'TXRH US EQUITY',
#     'PLAY US EQUITY'],
#    'Alpha Downside': 43.10705666684535,
#    'Alpha PT WIC': 59.057056666845355,
#    'Alpha Upside': 68.55705666684536}},
#  'overlap_peer_results': {'P/E': {'Overlap Peers': ['YUM US EQUITY',
#     'SBUX US EQUITY',
#     'BJRI US EQUITY'],
#    'Alpha Downside': 27.865942137388313,
#    'Alpha PT WIC': 43.81594213738831,
#    'Alpha Upside': 53.31594213738831},
#   'EV/EBITDA': {'Overlap Peers': ['YUM US EQUITY',
#     'SBUX US EQUITY',
#     'BJRI US EQUITY'],
#    'Alpha Downside': nan,
#    'Alpha PT WIC': nan,
#    'Alpha Upside': nan},
#   'EV/Sales': {'Overlap Peers': ['YUM US EQUITY',
#     'SBUX US EQUITY',
#     'BJRI US EQUITY'],
#    'Alpha Downside': nan,
#    'Alpha PT WIC': nan,
#    'Alpha Upside': nan},
#   'DVD Yield': {'Overlap Peers': ['YUM US EQUITY',
#     'SBUX US EQUITY',
#     'BJRI US EQUITY'],
#    'Alpha Downside': 28.720362339663406,
#    'Alpha PT WIC': 44.670362339663406,
#    'Alpha Upside': 54.170362339663406},
#   'FCF Yield': {'Overlap Peers': ['YUM US EQUITY',
#     'SBUX US EQUITY',
#     'BJRI US EQUITY'],
#    'Alpha Downside': 29.922967123789178,
#    'Alpha PT WIC': 45.87296712378918,
#    'Alpha Upside': 55.37296712378918}}}

# %%
def run_OLS_regression_analysis(alpha_ticker, unaffectedDt, tgtDate, analyst_upside, analyst_downside, analyst_pt_wic, api_host, lookback = 120, adjustments_df_now = None, adjustments_df_ptd = None, f_period = '1BF'):
    metrics = ['P/E', "EV/EBITDA", "EV/Sales", 'DVD Yield', 'FCF Yield']
    slicer = dfutils.df_slicer()
    unaff_dt = datetime.datetime.strptime(unaffectedDt, '%Y-%m-%d')
    price_tgt_dt = datetime.datetime.strptime(tgtDate, '%Y-%m-%d')
    as_of_dt = datetime.datetime.today()
    
    peer_ticker_list = OLS_regression_analysis.bloomberg_peers(alpha_ticker)
    
    alpha_historical_mult_df = OLS_regression_analysis.multiples_df(alpha_ticker, slicer.prev_n_business_days(lookback,unaff_dt).strftime('%Y%m%d'), unaff_dt.strftime('%Y%m%d'), api_host, fperiod) 
    peer2historical_mult_df = {p:OLS_regression_analysis.multiples_df(p,slicer.prev_n_business_days(lookback,unaff_dt).strftime('%Y%m%d'), unaff_dt.strftime('%Y%m%d'), api_host, fperiod, multiples_to_query=metrics) for p in peer_ticker_list}
    
    peer2ptd_multiple = {p:OLS_regression_analysis.multiples_df(p,slicer.prev_n_business_days(100,price_tgt_dt).strftime('%Y%m%d'),price_tgt_dt.strftime('%Y%m%d'),api_host,fperiod='1BF',multiples_to_query=metrics) for p in peer_ticker_list}
    peer2now_multiple = {p:OLS_regression_analysis.multiples_df(p,slicer.prev_n_business_days(100,as_of_dt).strftime('%Y%m%d'),as_of_dt.strftime('%Y%m%d'),api_host,fperiod='1BF',multiples_to_query=metrics) for p in peer_ticker_list}
    
    dataframes = {
        'alpha_historical_mult_df':alpha_historical_mult_df,
        'peer2historical_mult_df':peer2historical_mult_df,
        'peer2ptd_multiple': peer2ptd_multiple,
        'peer2now_multiple': peer2now_multiple
    }
    
    original_results = OLS_regression_analysis.premium_analysis_df_OLS_quick(dataframes, alpha_ticker, analyst_upside, lookback, unaffectedDt, tgtDate, metrics, api_host, fperiod = "1BF")

    adjusted_results = OLS_regression_analysis.premium_analysis_df_OLS2_quick(dataframes, alpha_ticker, analyst_upside, analyst_downside, analyst_pt_wic, lookback, unaffectedDt, tgtDate, metrics, api_host, adjustments_df_now = None, adjustments_df_ptd = None, fperiod = "1BF")
    
    return { 'original_results': original_results, 
            'adjusted_results': adjusted_results
           }

# %%
run_OLS_regression_analysis(alpha_ticker, unaffected_date, target_date, analyst_upside, analyst_downside, analyst_pt_wic, api_host, lookback = lookback, adjustments_df_now = None, adjustments_df_ptd = None, f_period = '1BF')
# Out:
# WARNING: ETM US EQUITY for BEST_EBITDA between 20180612 and 20181130 return mismatch date-value
# WARNING: ETM US EQUITY for BEST_OPP between 20180612 and 20181130 return mismatch date-value
# WARNING: ETM US EQUITY for BEST_CAPEX between 20180612 and 20181130 return mismatch date-value
# WARNING: ETM US EQUITY for BEST_NET_INCOME between 20180612 and 20181130 return mismatch date-value
# WARNING: LSXMA US EQUITY for BEST_EBITDA between 20180612 and 20181130 return mismatch date-value
# WARNING: LSXMA US EQUITY for BEST_OPP between 20180612 and 20181130 return mismatch date-value
# WARNING: LSXMA US EQUITY for BEST_NET_INCOME between 20180612 and 20181130 return mismatch date-value
# WARNING: ETM US EQUITY for BEST_EBITDA between 20180816 and 20190108 return mismatch date-value
# WARNING: ETM US EQUITY for BEST_EBITDA between 20180920 and 20190211 return mismatch date-value
# WARNING: LSXMA US EQUITY for BEST_CAPEX between 20180920 and 20190211 return mismatch date-value
# {'original_results': {'optimal_peer_results': {'P/E': {'Optimal Peers': ['TRCO US EQUITY',
#      'TGNA US EQUITY',
#      'SSP US EQUITY',
#      'GTN US EQUITY',
#      'WWE US EQUITY',
#      'ETM US EQUITY',
#      'LSXMA US EQUITY'],
#     'Alpha Downside': 64.32838794223917,
#     'Alpha Upside': 98.30764376894736},
#    'EV/EBITDA': {'Optimal Peers': ['SBGI US EQUITY',
#      'TRCO US EQUITY',
#      'TGNA US EQUITY',
#      'SSP US EQUITY',
#      'GTN US EQUITY',
#      'WWE US EQUITY',
#      'SIRI US EQUITY',
#      'ETM US EQUITY',
#      'LSXMA US EQUITY'],
#     'Alpha Downside': 67.74544268455925,
#     'Alpha Upside': 98.53135975951116},
#    'EV/Sales': {'Optimal Peers': ['SBGI US EQUITY',
#      'TRCO US EQUITY',
#      'TGNA US EQUITY',
#      'GTN US EQUITY',
#      'WWE US EQUITY',
#      'SIRI US EQUITY',
#      'ETM US EQUITY',
#      'LSXMA US EQUITY'],
#     'Alpha Downside': 75.35087346801097,
#     'Alpha Upside': 95.23557258225595},
#    'DVD Yield': {'Optimal Peers': ['SBGI US EQUITY',
#      'TRCO US EQUITY',
#      'TGNA US EQUITY',
#      'SSP US EQUITY',
#      'WWE US EQUITY',
#      'SIRI US EQUITY',
#      'ETM US EQUITY'],
#     'Alpha Downside': 90.95929714469264,
#     'Alpha Upside': 114.18587264310698},
#    'FCF Yield': {'Optimal Peers': ['SBGI US EQUITY',
#      'TRCO US EQUITY',
#      'TGNA US EQUITY',
#      'MDP US EQUITY',
#      'SSP US EQUITY',
#      'HMTV US EQUITY',
#      'GTN US EQUITY',
#      'ETM US EQUITY'],
#     'Alpha Downside': 138.00144268969393,
#     'Alpha Upside': 138.00144268969393}},
#   'overlap_peer_results': {'P/E': {'Overlap Peers': ['TRCO US EQUITY',
#      'TGNA US EQUITY',
#      'ETM US EQUITY'],
#     'Alpha Downside': 60.80801130182311,
#     'Alpha Upside': 99.78745481681568},
#    'EV/EBITDA': {'Overlap Peers': ['TRCO US EQUITY',
#      'TGNA US EQUITY',
#      'ETM US EQUITY'],
#     'Alpha Downside': 72.0168597115841,
#     'Alpha Upside': 99.37286658039227},
#    'EV/Sales': {'Overlap Peers': ['TRCO US EQUITY',
#      'TGNA US EQUITY',
#      'ETM US EQUITY'],
#     'Alpha Downside': 74.9258771711946,
#     'Alpha Upside': 99.58322456951277},
#    'DVD Yield': {'Overlap Peers': ['TRCO US EQUITY',
#      'TGNA US EQUITY',
#      'ETM US EQUITY'],
#     'Alpha Downside': 89.86308379465197,
#     'Alpha Upside': 113.25834099584912},
#    'FCF Yield': {'Overlap Peers': ['TRCO US EQUITY',
#      'TGNA US EQUITY',
#      'ETM US EQUITY'],
#     'Alpha Downside': 140.6224972780881,
#     'Alpha Upside': 140.6224972780881}}},
#  'adjusted_results': {'optimal_peer_results': {'P/E': {'Optimal Peers': ['TRCO US EQUITY',
#      'TGNA US EQUITY',
#      'SSP US EQUITY',
#      'GTN US EQUITY',
#      'WWE US EQUITY',
#      'ETM US EQUITY',
#      'LSXMA US EQUITY'],
#     'Alpha Downside': 61.80764376894736,
#     'Alpha PT WIC': 83.80764376894736,
#     'Alpha Upside': 98.30764376894736},
#    'EV/EBITDA': {'Optimal Peers': ['SBGI US EQUITY',
#      'TRCO US EQUITY',
#      'TGNA US EQUITY',
#      'SSP US EQUITY',
#      'GTN US EQUITY',
#      'WWE US EQUITY',
#      'SIRI US EQUITY',
#      'ETM US EQUITY',
#      'LSXMA US EQUITY'],
#     'Alpha Downside': 62.03135975951116,
#     'Alpha PT WIC': 84.03135975951116,
#     'Alpha Upside': 98.53135975951116},
#    'EV/Sales': {'Optimal Peers': ['SBGI US EQUITY',
#      'TRCO US EQUITY',
#      'TGNA US EQUITY',
#      'GTN US EQUITY',
#      'WWE US EQUITY',
#      'SIRI US EQUITY',
#      'ETM US EQUITY',
#      'LSXMA US EQUITY'],
#     'Alpha Downside': 58.735572582255955,
#     'Alpha PT WIC': 80.73557258225595,
#     'Alpha Upside': 95.23557258225595},
#    'DVD Yield': {'Optimal Peers': ['SBGI US EQUITY',
#      'TRCO US EQUITY',
#      'TGNA US EQUITY',
#      'SSP US EQUITY',
#      'WWE US EQUITY',
#      'SIRI US EQUITY',
#      'ETM US EQUITY'],
#     'Alpha Downside': 77.68587264310698,
#     'Alpha PT WIC': 99.68587264310698,
#     'Alpha Upside': 114.18587264310698},
#    'FCF Yield': {'Optimal Peers': ['SBGI US EQUITY',
#      'TRCO US EQUITY',
#      'TGNA US EQUITY',
#      'MDP US EQUITY',
#      'SSP US EQUITY',
#      'HMTV US EQUITY',
#      'GTN US EQUITY',
#      'ETM US EQUITY'],
#     'Alpha Downside': 61.868098550988776,
#     'Alpha PT WIC': 83.86809855098878,
#     'Alpha Upside': 98.36809855098878}},
#   'overlap_peer_results': {'P/E': {'Overlap Peers': ['TRCO US EQUITY',
#      'TGNA US EQUITY',
#      'ETM US EQUITY'],
#     'Alpha Downside': 63.28745481681569,
#     'Alpha PT WIC': 85.28745481681568,
#     'Alpha Upside': 99.78745481681568},
#    'EV/EBITDA': {'Overlap Peers': ['TRCO US EQUITY',
#      'TGNA US EQUITY',
#      'ETM US EQUITY'],
#     'Alpha Downside': 62.87286658039227,
#     'Alpha PT WIC': 84.87286658039227,
#     'Alpha Upside': 99.37286658039227},
#    'EV/Sales': {'Overlap Peers': ['TRCO US EQUITY',
#      'TGNA US EQUITY',
#      'ETM US EQUITY'],
#     'Alpha Downside': 63.083224569512765,
#     'Alpha PT WIC': 85.08322456951277,
#     'Alpha Upside': 99.58322456951277},
#    'DVD Yield': {'Overlap Peers': ['TRCO US EQUITY',
#      'TGNA US EQUITY',
#      'ETM US EQUITY'],
#     'Alpha Downside': 76.75834099584912,
#     'Alpha PT WIC': 98.75834099584912,
#     'Alpha Upside': 113.25834099584912},
#    'FCF Yield': {'Overlap Peers': ['TRCO US EQUITY',
#      'TGNA US EQUITY',
#      'ETM US EQUITY'],
#     'Alpha Downside': 62.32657790121101,
#     'Alpha PT WIC': 84.32657790121101,
#     'Alpha Upside': 98.82657790121101}}}}
